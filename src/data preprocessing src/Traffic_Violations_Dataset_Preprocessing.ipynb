# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# %% [markdown]
# **Website Scrapper Justia**

# %%
def process_subtitle(soup, title_num, subtitle_url):

    data = []


    section_pattern = f'/title-{title_num}/subtitle-\d+/section-{title_num}-\d+(?:-\d+)?/?$'
    section_data = find_links(soup, section_pattern, title_num)

    if section_data:

        for link_info in section_data:
            entry = {
                'Title': title_num,
                'Section': re.sub(r'^(\d+)-\d+-', r'\1-', link_info['section_number']),
                'Description': link_info['description'],
                'Path': 'Direct'
            }
            data.append(entry)
            print(f"Added subtitle section entry: {entry}")
            time.sleep(1)
    else:

        roman_numerals = ['i', 'ii', 'iii', 'iv', 'v', 'vi', 'vii', 'viii', 'ix', 'x']
        for numeral in roman_numerals:
            part_pattern = f'/title-{title_num}/subtitle-\d+/part-{numeral}/?$'
            part_links = soup.find_all('a', href=re.compile(part_pattern, re.IGNORECASE))

            for part_link in part_links:
                part_url = build_url(part_link['href'])
                print(f"\nProcessing roman numeral part: {part_url}")

                part_soup = fetch_page(part_url)
                if not part_soup:
                    continue


                part_section_pattern = f'/title-{title_num}/subtitle-\d+/part-{numeral}/section-{title_num}-\d+(?:-\d+)?/?$'
                part_section_data = find_links(part_soup, part_section_pattern, title_num)

                for link_info in part_section_data:
                    entry = {
                        'Title': title_num,
                        'Section': re.sub(r'^(\d+)-\d+-', r'\1-', link_info['section_number']),
                        'Description': link_info['description'],
                        'Path': f'Part {part_link.get_text(strip=True)}'
                    }
                    data.append(entry)
                    print(f"Added roman numeral part entry: {entry}")
                    time.sleep(1)

    return data

def process_title(title_num, title_url):
    """Process a single title and return its data"""
    data = []
    print(f"\nProcessing Title {title_num}: {title_url}")

    title_soup = fetch_page(title_url)
    if not title_soup:
        return data


    direct_section_pattern = f'/title-{title_num}/section-{title_num}-\d+(?:-\d+)?/?$'
    direct_section_data = find_links(title_soup, direct_section_pattern, title_num)

    for link_info in direct_section_data:
        entry = {
            'Title': title_num,
            'Section': re.sub(r'^(\d+)-\d+-', r'\1-', link_info['section_number']),
            'Description': link_info['description'],
            'Path': 'Direct'
        }
        data.append(entry)
        print(f"Added direct entry: {entry}")
        time.sleep(1)


    subtitle_pattern = f'/title-{title_num}/subtitle-\d+/?$'
    subtitle_links = title_soup.find_all('a', href=re.compile(subtitle_pattern))

    for subtitle_link in subtitle_links:
        subtitle_url = build_url(subtitle_link['href'])
        subtitle_number = subtitle_link['href'].split('subtitle-')[-1].strip('/')

        print(f"\nProcessing subtitle: {subtitle_url}")

        subtitle_soup = fetch_page(subtitle_url)
        if not subtitle_soup:
            continue


        subtitle_data = process_subtitle(subtitle_soup, title_num, subtitle_url)
        data.extend(subtitle_data)

    return data



def natural_sort_key(section):
    """Create a tuple key for natural sorting of section numbers"""
    parts = re.split(r'[-.]', section)
    return tuple(int(part) if part.isdigit() else part for part in parts)

def main():
    all_data = []

    titles = get_all_titles()

    print(f"Found {len(titles)} titles to process")

    for title_num, title_url in titles:
        title_data = process_title(title_num, title_url)

        all_data.extend(title_data)


        if all_data:
            df = pd.DataFrame(all_data)


            df['Title'] = pd.to_numeric(df['Title'])


            df.sort_values(['Title', 'Section'],
                           key=lambda x: x.map(lambda y: natural_sort_key(str(y)) if pd.notnull(y) else None),
                           inplace=True)

            df.to_csv('maryland_transportation_all_titles.csv', index=False)

            print(f"\nIntermediate save: {len(df)} total sections processed")


    if all_data:
        print("\nScraping complete. Final dataset:")

        df_final = pd.DataFrame(all_data)

        df_final.sort_values(['Title', 'Section'],
                             key=lambda x: x.map(lambda y: natural_sort_key(str(y)) if pd.notnull(y) else None),
                             inplace=True)

        df_final.to_csv('maryland_transportation_all_titles.csv', index=False)  # Save final DataFrame

        print(df_final.head())

        print(f"\nTotal sections: {len(df_final)}")

if __name__ == "__main__":
    main()
# Out:
# Found 27 titles to process
#
# Processing Title 1: https://law.justia.com/codes/maryland/transportation/title-1
# Found 3 links matching pattern: /title-1/section-1-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-1/section-1-101/ | Section: 1-1-101 | Description: Definitions
# Link found: /codes/maryland/transportation/title-1/section-1-102/ | Section: 1-1-102 | Description: Certificate of Compliance With Workers' Compensation Act
# Link found: /codes/maryland/transportation/title-1/section-1-103/ | Section: 1-1-103 | Description: Renewal of License or Permit; Verification of Payment of Taxes and Unemployment Insurance Contributions
# Added direct entry: {'Title': '1', 'Section': '1-101', 'Description': 'Definitions', 'Path': 'Direct'}
# Added direct entry: {'Title': '1', 'Section': '1-102', 'Description': "Certificate of Compliance With Workers' Compensation Act", 'Path': 'Direct'}
# Added direct entry: {'Title': '1', 'Section': '1-103', 'Description': 'Renewal of License or Permit; Verification of Payment of Taxes and Unemployment Insurance Contributions', 'Path': 'Direct'}
#
# Intermediate save: 3 total sections processed
#
# Processing Title 2: https://law.justia.com/codes/maryland/transportation/title-2
# Found 0 links matching pattern: /title-2/section-2-\d+(?:-\d+)?/?$
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-2/subtitle-1
# Found 17 links matching pattern: /title-2/subtitle-\d+/section-2-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-101/ | Section: 2-2-101 | Description: Department Established
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-102/ | Section: 2-2-102 | Description: Secretary of Transportation; Deputy Secretary; Assistants, Consultants, and Employees; Appointees
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103/ | Section: 2-2-103 | Description: General Authority and Duties of Secretary
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103-1/ | Section: 2-2-103.1 | Description: Annual Report
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103-2/ | Section: 2-2-103.2 | Description: Interest on Investments
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103-3/ | Section: 2-2-103.3 | Description: Funding of Service for Elderly Persons and Individuals With Disabilities
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103-4/ | Section: 2-2-103.4 | Description: Human Resources Management System
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103-5/ | Section: 2-2-103.5 | Description: Grants for Paratransit Service Provided by County or Local Governments
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103-6/ | Section: 2-2-103.6 | Description: Job Access Program
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103-7/ | Section: 2-2-103.7 | Description: Consolidated Transportation Program
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-103-8/ | Section: 2-2-103.8 | Description: Development of Urban Tree Program -- Purpose -- Collaboration to Identify Sources of Funding -- Inapplicable to Certain Transportation Projects
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-106/ | Section: 2-2-106 | Description: Counsel to Department
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-107/ | Section: 2-2-107 | Description: Units in Department
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-109/ | Section: 2-2-109 | Description: Waiver of Requirements for Competitive Bidding
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-110/ | Section: 2-2-110 | Description: Contracts for Waterborne Marine Fire Protection
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-111/ | Section: 2-2-111 | Description: Information Technology Investment Program
# Link found: /codes/maryland/transportation/title-2/subtitle-1/section-2-112/ | Section: 2-2-112 | Description: Complete Streets Policy
# Added subtitle section entry: {'Title': '2', 'Section': '2-101', 'Description': 'Department Established', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-102', 'Description': 'Secretary of Transportation; Deputy Secretary; Assistants, Consultants, and Employees; Appointees', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103', 'Description': 'General Authority and Duties of Secretary', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103.1', 'Description': 'Annual Report', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103.2', 'Description': 'Interest on Investments', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103.3', 'Description': 'Funding of Service for Elderly Persons and Individuals With Disabilities', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103.4', 'Description': 'Human Resources Management System', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103.5', 'Description': 'Grants for Paratransit Service Provided by County or Local Governments', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103.6', 'Description': 'Job Access Program', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103.7', 'Description': 'Consolidated Transportation Program', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-103.8', 'Description': 'Development of Urban Tree Program -- Purpose -- Collaboration to Identify Sources of Funding -- Inapplicable to Certain Transportation Projects', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-106', 'Description': 'Counsel to Department', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-107', 'Description': 'Units in Department', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-109', 'Description': 'Waiver of Requirements for Competitive Bidding', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-110', 'Description': 'Contracts for Waterborne Marine Fire Protection', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-111', 'Description': 'Information Technology Investment Program', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-112', 'Description': 'Complete Streets Policy', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-2/subtitle-2
# Found 5 links matching pattern: /title-2/subtitle-\d+/section-2-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-2/subtitle-2/section-2-201/ | Section: 2-2-201 | Description: "Commission" Defined
# Link found: /codes/maryland/transportation/title-2/subtitle-2/section-2-202/ | Section: 2-2-202 | Description: Commission Established
# Link found: /codes/maryland/transportation/title-2/subtitle-2/section-2-203/ | Section: 2-2-203 | Description: Composition; Qualifications; Tenure; Vacancies
# Link found: /codes/maryland/transportation/title-2/subtitle-2/section-2-204/ | Section: 2-2-204 | Description: Chairman; Meetings; Facilities and Personnel; Compensation and Expenses
# Link found: /codes/maryland/transportation/title-2/subtitle-2/section-2-205/ | Section: 2-2-205 | Description: Powers and Duties of Commission
# Added subtitle section entry: {'Title': '2', 'Section': '2-201', 'Description': '"Commission" Defined', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-202', 'Description': 'Commission Established', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-203', 'Description': 'Composition; Qualifications; Tenure; Vacancies', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-204', 'Description': 'Chairman; Meetings; Facilities and Personnel; Compensation and Expenses', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-205', 'Description': 'Powers and Duties of Commission', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-2/subtitle-4
# Found 3 links matching pattern: /title-2/subtitle-\d+/section-2-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-2/subtitle-4/section-2-401/ | Section: 2-2-401 | Description: Governor's Authority to Establish Highway Safety Program
# Link found: /codes/maryland/transportation/title-2/subtitle-4/section-2-402/ | Section: 2-2-402 | Description: Governor's Responsibility for Administration of Highway Safety Program
# Link found: /codes/maryland/transportation/title-2/subtitle-4/section-2-403/ | Section: 2-2-403 | Description: Administration of Highway Safety Program
# Added subtitle section entry: {'Title': '2', 'Section': '2-401', 'Description': "Governor's Authority to Establish Highway Safety Program", 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-402', 'Description': "Governor's Responsibility for Administration of Highway Safety Program", 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-403', 'Description': 'Administration of Highway Safety Program', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-2/subtitle-6
# Found 8 links matching pattern: /title-2/subtitle-\d+/section-2-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-2/subtitle-6/section-2-601/ | Section: 2-2-601 | Description: Definitions
# Link found: /codes/maryland/transportation/title-2/subtitle-6/section-2-602/ | Section: 2-2-602 | Description: Public Policy
# Link found: /codes/maryland/transportation/title-2/subtitle-6/section-2-603/ | Section: 2-2-603 | Description: Director of Bicycle and Pedestrian Access
# Link found: /codes/maryland/transportation/title-2/subtitle-6/section-2-604/ | Section: 2-2-604 | Description: Bicycle-Pedestrian Master Plan
# Link found: /codes/maryland/transportation/title-2/subtitle-6/section-2-605/ | Section: 2-2-605 | Description: Powers of Department
# Link found: /codes/maryland/transportation/title-2/subtitle-6/section-2-606/ | Section: 2-2-606 | Description: Bicycle and Pedestrian Advisory Committee
# Link found: /codes/maryland/transportation/title-2/subtitle-6/section-2-607/ | Section: 2-2-607 | Description: Pedestrian Safety Program
# Link found: /codes/maryland/transportation/title-2/subtitle-6/section-2-608/ | Section: 2-2-608 | Description: Kim Lamphier Bikeways Network Program -- Purpose
# Added subtitle section entry: {'Title': '2', 'Section': '2-601', 'Description': 'Definitions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-602', 'Description': 'Public Policy', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-603', 'Description': 'Director of Bicycle and Pedestrian Access', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-604', 'Description': 'Bicycle-Pedestrian Master Plan', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-605', 'Description': 'Powers of Department', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-606', 'Description': 'Bicycle and Pedestrian Advisory Committee', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-607', 'Description': 'Pedestrian Safety Program', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-608', 'Description': 'Kim Lamphier Bikeways Network Program -- Purpose', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-2/subtitle-7
# Found 3 links matching pattern: /title-2/subtitle-\d+/section-2-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-2/subtitle-7/section-2-701/ | Section: 2-2-701 | Description: Legislative Findings
# Link found: /codes/maryland/transportation/title-2/subtitle-7/section-2-702/ | Section: 2-2-702 | Description: Legislative Intent
# Link found: /codes/maryland/transportation/title-2/subtitle-7/section-2-703/ | Section: 2-2-703 | Description: Powers of Department
# Added subtitle section entry: {'Title': '2', 'Section': '2-701', 'Description': 'Legislative Findings', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-702', 'Description': 'Legislative Intent', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-703', 'Description': 'Powers of Department', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-2/subtitle-8
# Found 2 links matching pattern: /title-2/subtitle-\d+/section-2-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-2/subtitle-8/section-2-801/ | Section: 2-2-801 | Description: Operation of Pride of Baltimore Ii. [Effective Until July 1, 2028]
# Link found: /codes/maryland/transportation/title-2/subtitle-8/section-2-802/ | Section: 2-2-802 | Description: Grants Awarded to Eligible Grantees -- Actions by Department
# Added subtitle section entry: {'Title': '2', 'Section': '2-801', 'Description': 'Operation of Pride of Baltimore Ii. [Effective Until July 1, 2028]', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '2', 'Section': '2-802', 'Description': 'Grants Awarded to Eligible Grantees -- Actions by Department', 'Path': 'Direct'}
#
# Intermediate save: 41 total sections processed
#
# Processing Title 3: https://law.justia.com/codes/maryland/transportation/title-3
# Found 0 links matching pattern: /title-3/section-3-\d+(?:-\d+)?/?$
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-3/subtitle-1
# Found 4 links matching pattern: /title-3/subtitle-\d+/section-3-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-3/subtitle-1/section-3-101/ | Section: 3-3-101 | Description: Definitions
# Link found: /codes/maryland/transportation/title-3/subtitle-1/section-3-102/ | Section: 3-3-102 | Description: Continuation and Change of Resolution, Rules, Forms, Orders, and Directives; Certain References to Maryland Port Authority or State Roads Commission
# Link found: /codes/maryland/transportation/title-3/subtitle-1/section-3-103/ | Section: 3-3-103 | Description: Department of Transportation Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-1/section-3-104/ | Section: 3-3-104 | Description: Sinking Fund
# Added subtitle section entry: {'Title': '3', 'Section': '3-101', 'Description': 'Definitions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-102', 'Description': 'Continuation and Change of Resolution, Rules, Forms, Orders, and Directives; Certain References to Maryland Port Authority or State Roads Commission', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-103', 'Description': 'Department of Transportation Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-104', 'Description': 'Sinking Fund', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-3/subtitle-2
# Found 17 links matching pattern: /title-3/subtitle-\d+/section-3-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-201/ | Section: 3-3-201 | Description: General Power to Borrow Money and Issue Evidences of Obligation
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-202/ | Section: 3-3-202 | Description: Power to Issue Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-203/ | Section: 3-3-203 | Description: Procedure to Issue; Contents of Resolution; Postponement of Time for Receipt of Proposals
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-204/ | Section: 3-3-204 | Description: Execution of Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-205/ | Section: 3-3-205 | Description: Bonds and Other Evidences of Obligation Are Investment Securities
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-206/ | Section: 3-3-206 | Description: Exemption From  8-206 and 8-208 of State Finance and Procurement Article
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-207/ | Section: 3-3-207 | Description: Approval by Board of Public Works
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-208/ | Section: 3-3-208 | Description: Refunding Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-209/ | Section: 3-3-209 | Description: Interim Certificates and Temporary Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-210/ | Section: 3-3-210 | Description: Bond Anticipation Notes
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-211/ | Section: 3-3-211 | Description: Revenue Anticipation Notes
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-212/ | Section: 3-3-212 | Description: Exemption From Taxation
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-213/ | Section: 3-3-213 | Description: Full Faith and Credit Not Pledged
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-214/ | Section: 3-3-214 | Description: Termination of Power to Issue Obligations Under Certain Other Laws
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-215/ | Section: 3-3-215 | Description: Tax to Pay Principal and Interest; Sinking Fund
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-216/ | Section: 3-3-216 | Description: Transportation Trust Fund
# Link found: /codes/maryland/transportation/title-3/subtitle-2/section-3-217/ | Section: 3-3-217 | Description: Restriction on Transferring Funds in Transportation Trust Fund to General Fund or Special Fund; Repayment
# Added subtitle section entry: {'Title': '3', 'Section': '3-201', 'Description': 'General Power to Borrow Money and Issue Evidences of Obligation', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-202', 'Description': 'Power to Issue Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-203', 'Description': 'Procedure to Issue; Contents of Resolution; Postponement of Time for Receipt of Proposals', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-204', 'Description': 'Execution of Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-205', 'Description': 'Bonds and Other Evidences of Obligation Are Investment Securities', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-206', 'Description': 'Exemption From  8-206 and 8-208 of State Finance and Procurement Article', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-207', 'Description': 'Approval by Board of Public Works', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-208', 'Description': 'Refunding Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-209', 'Description': 'Interim Certificates and Temporary Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-210', 'Description': 'Bond Anticipation Notes', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-211', 'Description': 'Revenue Anticipation Notes', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-212', 'Description': 'Exemption From Taxation', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-213', 'Description': 'Full Faith and Credit Not Pledged', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-214', 'Description': 'Termination of Power to Issue Obligations Under Certain Other Laws', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-215', 'Description': 'Tax to Pay Principal and Interest; Sinking Fund', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-216', 'Description': 'Transportation Trust Fund', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-217', 'Description': 'Restriction on Transferring Funds in Transportation Trust Fund to General Fund or Special Fund; Repayment', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-3/subtitle-3
# Found 10 links matching pattern: /title-3/subtitle-\d+/section-3-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-301/ | Section: 3-3-301 | Description: Definitions
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-302/ | Section: 3-3-302 | Description: Purposes of Subtitle
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-303/ | Section: 3-3-303 | Description: Bonds Authorized
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-304/ | Section: 3-3-304 | Description: Participation of Counties
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-305/ | Section: 3-3-305 | Description: Determination of Amount; Subsequent Procedure
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-306/ | Section: 3-3-306 | Description: Limitations on Issuance
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-307/ | Section: 3-3-307 | Description: Agreement Between Department and County
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-308/ | Section: 3-3-308 | Description: Extraordinary Withholding by Comptroller
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-309/ | Section: 3-3-309 | Description: Bonds Are Departmental Debt
# Link found: /codes/maryland/transportation/title-3/subtitle-3/section-3-310/ | Section: 3-3-310 | Description: Provisions for Payment of Bonds
# Added subtitle section entry: {'Title': '3', 'Section': '3-301', 'Description': 'Definitions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-302', 'Description': 'Purposes of Subtitle', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-303', 'Description': 'Bonds Authorized', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-304', 'Description': 'Participation of Counties', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-305', 'Description': 'Determination of Amount; Subsequent Procedure', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-306', 'Description': 'Limitations on Issuance', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-307', 'Description': 'Agreement Between Department and County', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-308', 'Description': 'Extraordinary Withholding by Comptroller', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-309', 'Description': 'Bonds Are Departmental Debt', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-310', 'Description': 'Provisions for Payment of Bonds', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-3/subtitle-5
# Found 19 links matching pattern: /title-3/subtitle-\d+/section-3-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-501/ | Section: 3-3-501 | Description: Definitions
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-502/ | Section: 3-3-502 | Description: Purpose of Subtitle
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-503/ | Section: 3-3-503 | Description: Bonds Authorized
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-504/ | Section: 3-3-504 | Description: Resolution Authorizing Issuance of Bonds; Postponement of Time for Receipt of Proposals; Execution of Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-505/ | Section: 3-3-505 | Description: Bonds Are Investment Securities
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-506/ | Section: 3-3-506 | Description: Exemption From  8-206 and 8-208 of State Finance and Procurement Article
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-507/ | Section: 3-3-507 | Description: Interim Certificates and Temporary Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-508/ | Section: 3-3-508 | Description: Bond Anticipation Notes
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-509/ | Section: 3-3-509 | Description: Exemption From Taxation
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-510/ | Section: 3-3-510 | Description: Bonds Authorized by Trust Agreements
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-511/ | Section: 3-3-511 | Description: Consent of Instrumentality, Agency, or Unit of State Not Required
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-512/ | Section: 3-3-512 | Description: Provisions for Payment of Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-513/ | Section: 3-3-513 | Description: Bonds Not Debt of State or Department; Full Faith and Credit Not Pledged; Obligation of Participating Counties
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-514/ | Section: 3-3-514 | Description: Participation of Counties
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-515/ | Section: 3-3-515 | Description: Determination of Amount; Subsequent Procedure
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-516/ | Section: 3-3-516 | Description: Requirements for Participation of Counties
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-517/ | Section: 3-3-517 | Description: Agreement Between Department and County
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-518/ | Section: 3-3-518 | Description: Borrowing of Proceeds; Agreements to Participate in Bond Issue; Payment Obligations
# Link found: /codes/maryland/transportation/title-3/subtitle-5/section-3-519/ | Section: 3-3-519 | Description: Revenue Refunding Bonds
# Added subtitle section entry: {'Title': '3', 'Section': '3-501', 'Description': 'Definitions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-502', 'Description': 'Purpose of Subtitle', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-503', 'Description': 'Bonds Authorized', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-504', 'Description': 'Resolution Authorizing Issuance of Bonds; Postponement of Time for Receipt of Proposals; Execution of Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-505', 'Description': 'Bonds Are Investment Securities', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-506', 'Description': 'Exemption From  8-206 and 8-208 of State Finance and Procurement Article', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-507', 'Description': 'Interim Certificates and Temporary Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-508', 'Description': 'Bond Anticipation Notes', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-509', 'Description': 'Exemption From Taxation', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-510', 'Description': 'Bonds Authorized by Trust Agreements', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-511', 'Description': 'Consent of Instrumentality, Agency, or Unit of State Not Required', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-512', 'Description': 'Provisions for Payment of Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-513', 'Description': 'Bonds Not Debt of State or Department; Full Faith and Credit Not Pledged; Obligation of Participating Counties', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-514', 'Description': 'Participation of Counties', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-515', 'Description': 'Determination of Amount; Subsequent Procedure', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-516', 'Description': 'Requirements for Participation of Counties', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-517', 'Description': 'Agreement Between Department and County', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-518', 'Description': 'Borrowing of Proceeds; Agreements to Participate in Bond Issue; Payment Obligations', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-519', 'Description': 'Revenue Refunding Bonds', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-3/subtitle-6
# Found 7 links matching pattern: /title-3/subtitle-\d+/section-3-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-3/subtitle-6/section-3-601/ | Section: 3-3-601 | Description: Financing the Costs of Transportation Facilities
# Link found: /codes/maryland/transportation/title-3/subtitle-6/section-3-602/ | Section: 3-3-602 | Description: Special Transportation Project Revenue Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-6/section-3-603/ | Section: 3-3-603 | Description: Designation as Investment Securities; Exemption From Other Provisions
# Link found: /codes/maryland/transportation/title-3/subtitle-6/section-3-604/ | Section: 3-3-604 | Description: Refunding Bonds
# Link found: /codes/maryland/transportation/title-3/subtitle-6/section-3-605/ | Section: 3-3-605 | Description: Temporary Bonds and Bond Anticipation Notes
# Link found: /codes/maryland/transportation/title-3/subtitle-6/section-3-606/ | Section: 3-3-606 | Description: Trust Agreement
# Link found: /codes/maryland/transportation/title-3/subtitle-6/section-3-607/ | Section: 3-3-607 | Description: Exemption From Taxation; Additional Limitations
# Added subtitle section entry: {'Title': '3', 'Section': '3-601', 'Description': 'Financing the Costs of Transportation Facilities', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-602', 'Description': 'Special Transportation Project Revenue Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-603', 'Description': 'Designation as Investment Securities; Exemption From Other Provisions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-604', 'Description': 'Refunding Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-605', 'Description': 'Temporary Bonds and Bond Anticipation Notes', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-606', 'Description': 'Trust Agreement', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '3', 'Section': '3-607', 'Description': 'Exemption From Taxation; Additional Limitations', 'Path': 'Direct'}
#
# Intermediate save: 98 total sections processed
#
# Processing Title 4: https://law.justia.com/codes/maryland/transportation/title-4
# Found 0 links matching pattern: /title-4/section-4-\d+(?:-\d+)?/?$
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-4/subtitle-1
# Found 2 links matching pattern: /title-4/subtitle-\d+/section-4-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-4/subtitle-1/section-4-101/ | Section: 4-4-101 | Description: Definitions
# Link found: /codes/maryland/transportation/title-4/subtitle-1/section-4-102/ | Section: 4-4-102 | Description: Legislative Policy
# Added subtitle section entry: {'Title': '4', 'Section': '4-101', 'Description': 'Definitions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-102', 'Description': 'Legislative Policy', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-4/subtitle-2
# Found 13 links matching pattern: /title-4/subtitle-\d+/section-4-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-201/ | Section: 4-4-201 | Description: Authority Established
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-202/ | Section: 4-4-202 | Description: Chairman; Composition; Tenure; Vacancies; Compensation and Expenses
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-203/ | Section: 4-4-203 | Description: Staff of Authority
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-204/ | Section: 4-4-204 | Description: General Jurisdiction of Authority
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-205/ | Section: 4-4-205 | Description: General Powers of Authority
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-206/ | Section: 4-4-206 | Description: Power to Condemn Land for Certain Purposes
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-207/ | Section: 4-4-207 | Description: Power to Condemn Land for Certain Purposes -- Exemption of Authority From Taxation
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-208/ | Section: 4-4-208 | Description: Maryland Transportation Authority Police Force
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-208-1/ | Section: 4-4-208.1 | Description: Maryland Transportation Authority Police Force -- Chief Police Officer
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-209/ | Section: 4-4-209 | Description: Continuation and Change of Resolutions, Rules, Forms, Orders, and Directives; Certain References to Maryland Port Authority or State Roads Commission
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-210/ | Section: 4-4-210 | Description: Financial Forecast
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-211/ | Section: 4-4-211 | Description: Certain Visits or Tours Not Considered Meetings
# Link found: /codes/maryland/transportation/title-4/subtitle-2/section-4-212/ | Section: 4-4-212 | Description: Chesapeake Bay Bridge Reconstruction Advisory Group -- Members -- Terms -- Activities
# Added subtitle section entry: {'Title': '4', 'Section': '4-201', 'Description': 'Authority Established', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-202', 'Description': 'Chairman; Composition; Tenure; Vacancies; Compensation and Expenses', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-203', 'Description': 'Staff of Authority', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-204', 'Description': 'General Jurisdiction of Authority', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-205', 'Description': 'General Powers of Authority', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-206', 'Description': 'Power to Condemn Land for Certain Purposes', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-207', 'Description': 'Power to Condemn Land for Certain Purposes -- Exemption of Authority From Taxation', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-208', 'Description': 'Maryland Transportation Authority Police Force', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-208.1', 'Description': 'Maryland Transportation Authority Police Force -- Chief Police Officer', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-209', 'Description': 'Continuation and Change of Resolutions, Rules, Forms, Orders, and Directives; Certain References to Maryland Port Authority or State Roads Commission', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-210', 'Description': 'Financial Forecast', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-211', 'Description': 'Certain Visits or Tours Not Considered Meetings', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-212', 'Description': 'Chesapeake Bay Bridge Reconstruction Advisory Group -- Members -- Terms -- Activities', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-4/subtitle-3
# Found 24 links matching pattern: /title-4/subtitle-\d+/section-4-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-301/ | Section: 4-4-301 | Description: General Power to Borrow Money and Issue Evidences of Obligation
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-302/ | Section: 4-4-302 | Description: Power to Issue Revenue Bonds and Determine Related Matters
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-303/ | Section: 4-4-303 | Description: Execution of Bonds
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-304/ | Section: 4-4-304 | Description: Bonds and Other Evidences of Obligation Are Investment Securities
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-305/ | Section: 4-4-305 | Description: Exemption From  8-206 and 8-208 of State Finance and Procurement Article
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-306/ | Section: 4-4-306 | Description: Other Approval Not Required; Exceptions
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-307/ | Section: 4-4-307 | Description: Additional Bonds
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-308/ | Section: 4-4-308 | Description: Revenue Refunding Bonds
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-309/ | Section: 4-4-309 | Description: Interim Certificates and Temporary Bonds
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-310/ | Section: 4-4-310 | Description: Bond Anticipation Notes
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-311/ | Section: 4-4-311 | Description: Trust Agreement Securing Bonds
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-311-1/ | Section: 4-4-311.1 | Description: Vehicle Parking Facility Financing
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-312/ | Section: 4-4-312 | Description: Charges for Transportation Facilities Projects
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-312-1/ | Section: 4-4-312.1 | Description: Elimination of Ramp Tolls on Kennedy Highway in Harford and Cecil Counties
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-313/ | Section: 4-4-313 | Description: Transportation Authority Fund
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-314/ | Section: 4-4-314 | Description: Construction of Subtitle
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-315/ | Section: 4-4-315 | Description: Trust Funds
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-316/ | Section: 4-4-316 | Description: Remedies of Bondholder and Trustee
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-317/ | Section: 4-4-317 | Description: Bonds and Other Evidences of Obligation Are Legal Investments
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-318/ | Section: 4-4-318 | Description: Exemption From Taxation
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-319/ | Section: 4-4-319 | Description: Full Faith and Credit Not Pledged
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-320/ | Section: 4-4-320 | Description: Limitation on Use of Federal Aid for Repayment of Bonds; Lien and Priorities in Event of Shortfall
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-320-1/ | Section: 4-4-320.1 | Description: Bond Anticipation Notes
# Link found: /codes/maryland/transportation/title-4/subtitle-3/section-4-321/ | Section: 4-4-321 | Description: Intercounty Connector
# Added subtitle section entry: {'Title': '4', 'Section': '4-301', 'Description': 'General Power to Borrow Money and Issue Evidences of Obligation', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-302', 'Description': 'Power to Issue Revenue Bonds and Determine Related Matters', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-303', 'Description': 'Execution of Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-304', 'Description': 'Bonds and Other Evidences of Obligation Are Investment Securities', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-305', 'Description': 'Exemption From  8-206 and 8-208 of State Finance and Procurement Article', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-306', 'Description': 'Other Approval Not Required; Exceptions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-307', 'Description': 'Additional Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-308', 'Description': 'Revenue Refunding Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-309', 'Description': 'Interim Certificates and Temporary Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-310', 'Description': 'Bond Anticipation Notes', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-311', 'Description': 'Trust Agreement Securing Bonds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-311.1', 'Description': 'Vehicle Parking Facility Financing', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-312', 'Description': 'Charges for Transportation Facilities Projects', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-312.1', 'Description': 'Elimination of Ramp Tolls on Kennedy Highway in Harford and Cecil Counties', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-313', 'Description': 'Transportation Authority Fund', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-314', 'Description': 'Construction of Subtitle', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-315', 'Description': 'Trust Funds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-316', 'Description': 'Remedies of Bondholder and Trustee', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-317', 'Description': 'Bonds and Other Evidences of Obligation Are Legal Investments', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-318', 'Description': 'Exemption From Taxation', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-319', 'Description': 'Full Faith and Credit Not Pledged', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-320', 'Description': 'Limitation on Use of Federal Aid for Repayment of Bonds; Lien and Priorities in Event of Shortfall', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-320.1', 'Description': 'Bond Anticipation Notes', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-321', 'Description': 'Intercounty Connector', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-4/subtitle-4
# Found 7 links matching pattern: /title-4/subtitle-\d+/section-4-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-4/subtitle-4/section-4-401/ | Section: 4-4-401 | Description: Control of Entrances and Exits
# Link found: /codes/maryland/transportation/title-4/subtitle-4/section-4-402/ | Section: 4-4-402 | Description: Traffic Delay Signs for Baltimore Harbor Tunnel
# Link found: /codes/maryland/transportation/title-4/subtitle-4/section-4-403/ | Section: 4-4-403 | Description: Railroad Tracks on Kennedy Highway Prohibited
# Link found: /codes/maryland/transportation/title-4/subtitle-4/section-4-404/ | Section: 4-4-404 | Description: Service Facilities on Kennedy Highway
# Link found: /codes/maryland/transportation/title-4/subtitle-4/section-4-405/ | Section: 4-4-405 | Description: Informational Signs
# Link found: /codes/maryland/transportation/title-4/subtitle-4/section-4-406/ | Section: 4-4-406 | Description: Harry W. Nice/thomas "Mac" Middleton Bridge
# Link found: /codes/maryland/transportation/title-4/subtitle-4/section-4-407/ | Section: 4-4-407 | Description: Construction of Toll Roads
# Added subtitle section entry: {'Title': '4', 'Section': '4-401', 'Description': 'Control of Entrances and Exits', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-402', 'Description': 'Traffic Delay Signs for Baltimore Harbor Tunnel', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-403', 'Description': 'Railroad Tracks on Kennedy Highway Prohibited', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-404', 'Description': 'Service Facilities on Kennedy Highway', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-405', 'Description': 'Informational Signs', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-406', 'Description': 'Harry W. Nice/thomas "Mac" Middleton Bridge', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '4', 'Section': '4-407', 'Description': 'Construction of Toll Roads', 'Path': 'Direct'}
#
# Intermediate save: 144 total sections processed
#
# Processing Title 5: https://law.justia.com/codes/maryland/transportation/title-5
# Found 0 links matching pattern: /title-5/section-5-\d+(?:-\d+)?/?$
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-5/subtitle-1
# Found 6 links matching pattern: /title-5/subtitle-\d+/section-5-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-5/subtitle-1/section-5-101/ | Section: 5-5-101 | Description: Definitions
# Link found: /codes/maryland/transportation/title-5/subtitle-1/section-5-102/ | Section: 5-5-102 | Description: Legislative Policy
# Link found: /codes/maryland/transportation/title-5/subtitle-1/section-5-103/ | Section: 5-5-103 | Description: Jurisdiction Over Crimes, Torts, Wrongs, and Contracts
# Link found: /codes/maryland/transportation/title-5/subtitle-1/section-5-104/ | Section: 5-5-104 | Description: Sovereignty in and Ownership of Space
# Link found: /codes/maryland/transportation/title-5/subtitle-1/section-5-105/ | Section: 5-5-105 | Description: Local Appropriations
# Link found: /codes/maryland/transportation/title-5/subtitle-1/section-5-106/ | Section: 5-5-106 | Description: Airport in Sixth Election District of Queen Anne's County Prohibited
# Added subtitle section entry: {'Title': '5', 'Section': '5-101', 'Description': 'Definitions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '5', 'Section': '5-102', 'Description': 'Legislative Policy', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '5', 'Section': '5-103', 'Description': 'Jurisdiction Over Crimes, Torts, Wrongs, and Contracts', 'Path': 'Direct'}
# ...
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-202/ | Section: 25-25-202 | Description: Abandonment of Vehicles Prohibited; Presumption of Ownership
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-203/ | Section: 25-25-203 | Description: Police May Take Abandoned Vehicles Into Custody
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-204/ | Section: 25-25-204 | Description: Notice by Police to Last Known Registered Owner and Secured Parties -- in General
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-205/ | Section: 25-25-205 | Description: Notice by Police to Last Known Registered Owner and Secured Parties -- Notice by Publication
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-206/ | Section: 25-25-206 | Description: Effect of Failure to Reclaim Vehicle
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-206-1/ | Section: 25-25-206.1 | Description: Liability for Costs of Preservation and Storage of Vehicle
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-206-2/ | Section: 25-25-206.2 | Description: Restrictions on Vehicle Registration for Liability Incurred Under  25-206.1
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-207/ | Section: 25-25-207 | Description: Sale of Vehicle; Disposition of Proceeds
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-207-1/ | Section: 25-25-207.1 | Description: Abandoned or Impounded Vehicles With Removed or Defaced Serial Numbers
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-208/ | Section: 25-25-208 | Description: Special Provisions for Vehicles Abandoned in Garages
# Link found: /codes/maryland/transportation/title-25/subtitle-2/section-25-209/ | Section: 25-25-209 | Description: Disposition of Vehicles to Dismantler and Recycler or Scrap Processor -- in General
# Added subtitle section entry: {'Title': '25', 'Section': '25-201', 'Description': 'Definitions', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-202', 'Description': 'Abandonment of Vehicles Prohibited; Presumption of Ownership', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-203', 'Description': 'Police May Take Abandoned Vehicles Into Custody', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-204', 'Description': 'Notice by Police to Last Known Registered Owner and Secured Parties -- in General', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-205', 'Description': 'Notice by Police to Last Known Registered Owner and Secured Parties -- Notice by Publication', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-206', 'Description': 'Effect of Failure to Reclaim Vehicle', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-206.1', 'Description': 'Liability for Costs of Preservation and Storage of Vehicle', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-206.2', 'Description': 'Restrictions on Vehicle Registration for Liability Incurred Under  25-206.1', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-207', 'Description': 'Sale of Vehicle; Disposition of Proceeds', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-207.1', 'Description': 'Abandoned or Impounded Vehicles With Removed or Defaced Serial Numbers', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-208', 'Description': 'Special Provisions for Vehicles Abandoned in Garages', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '25', 'Section': '25-209', 'Description': 'Disposition of Vehicles to Dismantler and Recycler or Scrap Processor -- in General', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-25/subtitle-3
# Found 1 links matching pattern: /title-25/subtitle-\d+/section-25-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-25/subtitle-3/section-25-301/ | Section: 25-25-301 | Description: Potomac River Bridges Towing Compact
# Added subtitle section entry: {'Title': '25', 'Section': '25-301', 'Description': 'Potomac River Bridges Towing Compact', 'Path': 'Direct'}
#
# Intermediate save: 1638 total sections processed
#
# Processing Title 26: https://law.justia.com/codes/maryland/transportation/title-26
# Found 0 links matching pattern: /title-26/section-26-\d+(?:-\d+)?/?$
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-26/subtitle-1
# Found 3 links matching pattern: /title-26/subtitle-\d+/section-26-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-26/subtitle-1/section-26-101/ | Section: 26-26-101 | Description: Parties to an Offense
# Link found: /codes/maryland/transportation/title-26/subtitle-1/section-26-102/ | Section: 26-26-102 | Description: Offense by Person Owning or Controlling Vehicle
# Link found: /codes/maryland/transportation/title-26/subtitle-1/section-26-103/ | Section: 26-26-103 | Description: Application of Titles 20 Through 24 to Federal, State, and Local Vehicles
# Added subtitle section entry: {'Title': '26', 'Section': '26-101', 'Description': 'Parties to an Offense', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-102', 'Description': 'Offense by Person Owning or Controlling Vehicle', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-103', 'Description': 'Application of Titles 20 Through 24 to Federal, State, and Local Vehicles', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-26/subtitle-2
# Found 6 links matching pattern: /title-26/subtitle-\d+/section-26-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-26/subtitle-2/section-26-201/ | Section: 26-26-201 | Description: Authority to Charge; Issuance and Contents of Traffic Citations
# Link found: /codes/maryland/transportation/title-26/subtitle-2/section-26-202/ | Section: 26-26-202 | Description: Power of Arrest
# Link found: /codes/maryland/transportation/title-26/subtitle-2/section-26-203/ | Section: 26-26-203 | Description: Signature of Person Charged Required on Citation
# Link found: /codes/maryland/transportation/title-26/subtitle-2/section-26-204/ | Section: 26-26-204 | Description: Compliance With Traffic Citations; Powers of the Court on Noncompliance
# Link found: /codes/maryland/transportation/title-26/subtitle-2/section-26-206/ | Section: 26-26-206 | Description: Noncompliance With Traffic Citation Issued Under Federal Law
# Link found: /codes/maryland/transportation/title-26/subtitle-2/section-26-207/ | Section: 26-26-207 | Description: Sanctions for Noncompliance With Foreign State Law
# Added subtitle section entry: {'Title': '26', 'Section': '26-201', 'Description': 'Authority to Charge; Issuance and Contents of Traffic Citations', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-202', 'Description': 'Power of Arrest', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-203', 'Description': 'Signature of Person Charged Required on Citation', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-204', 'Description': 'Compliance With Traffic Citations; Powers of the Court on Noncompliance', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-206', 'Description': 'Noncompliance With Traffic Citation Issued Under Federal Law', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-207', 'Description': 'Sanctions for Noncompliance With Foreign State Law', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-26/subtitle-3
# Found 7 links matching pattern: /title-26/subtitle-\d+/section-26-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-26/subtitle-3/section-26-301/ | Section: 26-26-301 | Description: Power of Political Subdivisions and State Agencies to Regulate Parking
# Link found: /codes/maryland/transportation/title-26/subtitle-3/section-26-301-1/ | Section: 26-26-301.1 | Description: Motorcycle Parking
# Link found: /codes/maryland/transportation/title-26/subtitle-3/section-26-302/ | Section: 26-26-302 | Description: Citations for Parking Violations
# Link found: /codes/maryland/transportation/title-26/subtitle-3/section-26-303/ | Section: 26-26-303 | Description: Election to Pay or Stand Trial; Presence of Officer at Trial
# Link found: /codes/maryland/transportation/title-26/subtitle-3/section-26-304/ | Section: 26-26-304 | Description: Adoption of Procedures by Chief Judge
# Link found: /codes/maryland/transportation/title-26/subtitle-3/section-26-305/ | Section: 26-26-305 | Description: Effect of Parking Violation on Vehicle Registration
# Link found: /codes/maryland/transportation/title-26/subtitle-3/section-26-306/ | Section: 26-26-306 | Description: Reimbursement of Owner of Vehicle Wrongfully Towed, Impounded, or Stored
# Added subtitle section entry: {'Title': '26', 'Section': '26-301', 'Description': 'Power of Political Subdivisions and State Agencies to Regulate Parking', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-301.1', 'Description': 'Motorcycle Parking', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-302', 'Description': 'Citations for Parking Violations', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-303', 'Description': 'Election to Pay or Stand Trial; Presence of Officer at Trial', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-304', 'Description': 'Adoption of Procedures by Chief Judge', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-305', 'Description': 'Effect of Parking Violation on Vehicle Registration', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-306', 'Description': 'Reimbursement of Owner of Vehicle Wrongfully Towed, Impounded, or Stored', 'Path': 'Direct'}
#
# Processing subtitle: https://law.justia.com/codes/maryland/transportation/title-26/subtitle-4
# Found 12 links matching pattern: /title-26/subtitle-\d+/section-26-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-401/ | Section: 26-26-401 | Description: Venue
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-402/ | Section: 26-26-402 | Description: Release of Defendant if Commissioner Not Available
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-403/ | Section: 26-26-403 | Description: Bail
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-404/ | Section: 26-26-404 | Description: Guaranteed Arrest Bond Certificate
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-405/ | Section: 26-26-405 | Description: Lesser Included Offenses Under  21-901.1 and 21-902
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-405-1/ | Section: 26-26-405.1 | Description: Disposition of Penalty Deposit
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-407/ | Section: 26-26-407 | Description: Disposition and Records of Traffic Citations
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-408/ | Section: 26-26-408 | Description: Cancellation or Solicitation of Cancellation of Traffic Citation
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-409/ | Section: 26-26-409 | Description: When Copy of Citation Is Sufficient Charging Document; Case to Be Tried Only on Proper Charging Document
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-410/ | Section: 26-26-410 | Description: Fees for Sheriffs
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-411/ | Section: 26-26-411 | Description: Witness Fees for Officers Prohibited
# Link found: /codes/maryland/transportation/title-26/subtitle-4/section-26-412/ | Section: 26-26-412 | Description: Conflict With Courts Article
# Added subtitle section entry: {'Title': '26', 'Section': '26-401', 'Description': 'Venue', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-402', 'Description': 'Release of Defendant if Commissioner Not Available', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-403', 'Description': 'Bail', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-404', 'Description': 'Guaranteed Arrest Bond Certificate', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-405', 'Description': 'Lesser Included Offenses Under  21-901.1 and 21-902', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-405.1', 'Description': 'Disposition of Penalty Deposit', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-407', 'Description': 'Disposition and Records of Traffic Citations', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-408', 'Description': 'Cancellation or Solicitation of Cancellation of Traffic Citation', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-409', 'Description': 'When Copy of Citation Is Sufficient Charging Document; Case to Be Tried Only on Proper Charging Document', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-410', 'Description': 'Fees for Sheriffs', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-411', 'Description': 'Witness Fees for Officers Prohibited', 'Path': 'Direct'}
# Added subtitle section entry: {'Title': '26', 'Section': '26-412', 'Description': 'Conflict With Courts Article', 'Path': 'Direct'}
#
# Intermediate save: 1666 total sections processed
#
# Processing Title 27: https://law.justia.com/codes/maryland/transportation/title-27
# Found 4 links matching pattern: /title-27/section-27-\d+(?:-\d+)?/?$
# Link found: /codes/maryland/transportation/title-27/section-27-101/ | Section: 27-27-101 | Description: Misdemeanor -- Penalties; Exceptions
# Link found: /codes/maryland/transportation/title-27/section-27-102/ | Section: 27-27-102 | Description: Misdemeanor -- Violation of License Restriction or Regulation
# Link found: /codes/maryland/transportation/title-27/section-27-103/ | Section: 27-27-103 | Description: Payment of Outstanding Fines -- Notice
# Link found: /codes/maryland/transportation/title-27/section-27-104/ | Section: 27-27-104 | Description: Reimbursement of Forfeited Bond or Collateral
# Added direct entry: {'Title': '27', 'Section': '27-101', 'Description': 'Misdemeanor -- Penalties; Exceptions', 'Path': 'Direct'}
# Added direct entry: {'Title': '27', 'Section': '27-102', 'Description': 'Misdemeanor -- Violation of License Restriction or Regulation', 'Path': 'Direct'}
# Added direct entry: {'Title': '27', 'Section': '27-103', 'Description': 'Payment of Outstanding Fines -- Notice', 'Path': 'Direct'}
# Added direct entry: {'Title': '27', 'Section': '27-104', 'Description': 'Reimbursement of Forfeited Bond or Collateral', 'Path': 'Direct'}
#
# Intermediate save: 1670 total sections processed
#
# Scraping complete. Final dataset:
#   Title Section                                        Description    Path
# 0     1   1-101                                        Definitions  Direct
# 1     1   1-102  Certificate of Compliance With Workers' Compen...  Direct
# 2     1   1-103  Renewal of License or Permit; Verification of ...  Direct
# 3     2   2-101                             Department Established  Direct
# 4     2   2-102  Secretary of Transportation; Deputy Secretary;...  Direct
#
# Total sections: 1670

# %% [markdown]
# **Dataset Loading and Dropping any null instances for Driver State**

# %%
df = pd.read_csv('Traffic_Violations_20241223.csv')
df = df.dropna(subset=['Driver State'])
# Out:
# <ipython-input-9-b34f07558136>:1: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Traffic_Violations_20241223.csv')

# %% [markdown]
# **Stratified Sampling**

# %%
total_points = 100000
frac_per_state = total_points / len(df)

stratified_sample = df.groupby('Driver State', group_keys=False).apply(
    lambda x: x.sample(frac=frac_per_state, random_state=30)
)


stratified_sample.reset_index(drop=True, inplace=True)


stratified_sample.to_csv('Sampled_Traffic_Violations.csv', index=False)
# Out:
# <ipython-input-28-f8f5cc314790>:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stratified_sample = df.groupby('Driver State', group_keys=False).apply(

# %% [markdown]
# **Creating Charge_Abbreviation Attribute**

# %%
us_state_abbreviations = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
    'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ',
    'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT',
    'VA', 'WA', 'WV', 'WI', 'WY',
]

df['Charge_Abbreviation'] = df['Charge'].str[:8]
# Out:
# 2
# Presence and count of each U.S. state abbreviation in the dataset:
# Nothing: 13
# Contraband Only: 7

# %%
df = pd.read_csv('Sampled_Traffic_Violations.csv')

# %%
df['Charge_Abbreviation'] = df['Charge'].str.extract(r'^([^(]*)').fillna('')


df['Charge_Abbreviation'] = df['Charge_Abbreviation'].str.strip()
# Out:
# Index(['SeqID', 'Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency',
#        'Description', 'Location', 'Latitude', 'Longitude', 'Accident', 'Belts',
#        'Personal Injury', 'Property Damage', 'Fatal', 'Commercial License',
#        'HAZMAT', 'Commercial Vehicle', 'Alcohol', 'Work Zone',
#        'Search Conducted', 'Search Disposition', 'Search Outcome',
#        'Search Reason', 'Search Reason For Stop', 'Search Type',
#        'Search Arrest Reason', 'State', 'VehicleType', 'Year', 'Make', 'Model',
#        'Color', 'Violation Type', 'Charge', 'Article',
#        'Contributed To Accident', 'Race', 'Gender', 'Driver City',
#        'Driver State', 'DL State', 'Arrest Type', 'Geolocation',
#        'Charge_Abbreviation'],
#       dtype='object')
# Total unique charges: 5
#
# Presence and count of each charge abbreviation in the dataset:
# WHITE: 226
# BLACK: 226
# HISPANIC: 168
# ASIAN: 70
# OTHER: 70

# %% [markdown]
# **Adding Unknown values for Search Conducted and Search Outcome attribute**

# %%
df['Search Conducted'] = df['Search Conducted'].fillna('Unknown')


df.loc[df['Search Conducted'] == 'Unknown', 'Search Outcome'] = 'Unknown'
df.loc[df['Search Conducted'] == 'Unknown', 'Search Reason For Stop'] = 'Unknown'



state_filter_df = df[df.State.isin(us_state_abbreviations)]


state_filter_df.to_csv('Sampled_Traffic_Violations.csv', index=False)

# %%
df1 = pd.read_csv('maryland_transportation_all_titles.csv')
df1 = df1.drop(columns=['Title', 'Path'])

# %% [markdown]
# **Merging and Dropping**

# %%
merged_df = pd.merge(df, df1, left_on='Charge_Abbreviation', right_on='Section', how='left')

merged_df = merged_df.drop(columns=['Geolocation'])
merged_df.to_csv('maryland_traffic_violations.csv', index=False)

# %%
df2 = pd.read_csv('ESERO Code.csv')

# %% [markdown]
# **Merging**

# %%
merged_df = pd.merge(merged_df, df2, left_on='Charge_Abbreviation', right_on='Number', how='left')


merged_df['Charge Hierarchy'] = merged_df['Charge_Abbreviation'].replace('', None).fillna(merged_df['Number'])


merged_df['Charge Description'] = merged_df['Description_y'].replace('', None).fillna(merged_df.get('Description_yy'))

# %%
merged_df = merged_df.drop(columns=['Charge_Abbreviation', 'Description_y', 'Description_yy', 'Number', 'Section', 'Article'])

# %%
merged_df = merged_df[merged_df['Latitude'] != 0]

# %% [markdown]
# **Unique Instances**

# %%
df1 = pd.read_csv('Transcode1.csv')
df2 = pd.read_csv('Transcode2.csv')


combined_df = pd.concat([df1, df2])


def create_charge(row):
    title = int(row['Title'])


    section = float(row['Section'])

    if section.is_integer():
        section_str = str(int(section))
    else:
        section_str = str(section)

    if pd.isna(row['Subsection']) or str(row['Subsection']).strip() == '':
        return f"{title}-{section_str}"
    else:
        return f"{title}-{section_str}({row['Subsection']})"


def clean_description(text):
    if pd.isna(text):
        return text

    parts = text.split('..')

    cleaned = parts[0].strip()
    return cleaned

combined_df['Charge'] = combined_df.apply(create_charge, axis=1)


combined_df['Description'] = combined_df['Description'].apply(clean_description)

s
unique_df = combined_df.drop_duplicates(subset='Charge')
unique_df = unique_df[['Charge'] + [col for col in unique_df.columns if col != 'Charge']]
unique_df = unique_df.drop(columns=['Title', 'Section', 'Subsection'])


unique_df['Fine Description'] = unique_df['Description'].str.extract(r'^([A-Za-z0-9\s]+)')[0].str.strip()

# %%
merged_df = pd.merge(merged_df, unique_df, left_on='Charge', right_on='Charge', how='left')

# %% [markdown]
# **Adding Additional Fine Values**

# %%
def get_fine_details(speed):
    if speed >= 1 and speed <= 9:
        return {'Fine': '$80.00', 'Points': 1, 'Contr.Acc Fine': '$120.00', 'Contr.Acc Points': 3}
    elif speed >= 10 and speed <= 19:
        return {'Fine': '$90.00', 'Points': 2, 'Contr.Acc Fine': '$130.00', 'Contr.Acc Points': 3}
    elif speed >= 20 and speed <= 29:
        return {'Fine': '$160.00', 'Points': 2, 'Contr.Acc Fine': '$200.00', 'Contr.Acc Points': 3}
    elif speed >= 30 and speed <= 39:
        return {'Fine': '$290.00', 'Points': 5, 'Contr.Acc Fine': '$290.00', 'Contr.Acc Points': 5}

    elif speed >= 40:
        return {'Fine': '$530.00', 'Points': 5, 'Contr.Acc Fine': '$530.00', 'Contr.Acc Points': 5}
    else:
        return {'Fine': '$0.00', 'Points': 0, 'Contr.Acc Fine': '$0.00', 'Contr.Acc Points': 0}


def extract_speed(description):
    match = re.search(r'(\d{2,3})\s*MPH', description)
    if match:
        return int(match.group(1))
    return None


def update_fine_details(row):

    if row['Charge'] == '21-801.1':
        speed = extract_speed(row['Description_x'])
        if speed is not None:
            fine_details = get_fine_details(speed)
            row['Fine'] = fine_details['Fine']
            row['Points'] = fine_details['Points']
            row['Contr.Acc Fine'] = fine_details['Contr.Acc Fine']
            row['Contr.Acc Points'] = fine_details['Contr.Acc Points']


    if row['Charge'] == '16-112(c)':
        row['Fine'] = '$50.00'
        row['Points'] = 0
        row['Contr.Acc Fine'] = '$50.00'
        row['Contr.Acc Points'] = 0
        row['Description'] = 'Failure of individual driving on hwy. to display lic. to uniformed police on demand'


    if row['Charge'] == '21-1124.2(d2)':
        row['Fine'] = '$83.00'
        row['Points'] = 0
        row['Contr.Acc Fine'] = '$83.00'
        row['Contr.Acc Points'] = 0
        row['Description'] = 'Driver using hands to use handheld telephone while motor vehicle is in motion'


    if row['Charge'] == '16-303(c)':
        row['Fine'] = 'MA'
        row['Points'] = 12
        row['Contr.Acc Fine'] = 'MA'
        row['Contr.Acc Points'] = 12
        row['Description'] = 'Driver using hands to use handheld telephone while motor vehicle is in motion'

    if row['Charge'] == '16-303(h)':
        row['Fine'] = 'MA'
        row['Points'] = 12
        row['Contr.Acc Fine'] = 'MA'
        row['Contr.Acc Points'] = 12
        row['Description'] = 'Driving motor veh. while lic. suspended under TR'


    if row['Charge'] == '22-412.3(b)':
        row['Fine'] = '$83.00'
        row['Points'] = 0
        row['Contr.Acc Fine'] = '$83.00'
        row['Contr.Acc Points'] = 0
        row['Description'] = 'Oper. motor veh. with (operator, occupant under age 16) not restrained by (seat belt, child safety seat)'


    if row['Charge'] == '16-101(a)' or row['Charge'] == '16-101(a1)':
        row['Fine'] = 'MA'
        row['Points'] = 5
        row['Contr.Acc Fine'] = 'MA'
        row['Contr.Acc Points'] = 5
        row['Description'] = 'Driving, Attempting to drive) motor veh. on hwy. without req. license and authorization'


    if row['Charge'] == '21-901.1(b)':
        row['Fine'] = '$240.00'
        row['Points'] = 1
        row['Contr.Acc Fine'] = '$280.00'
        row['Contr.Acc Points'] = 3
        row['Description'] = 'Negligent driving veh. in careless and imprudent manner endangering property, life, and person'


    if row['Charge'] == '22-201.1':
        row['Fine'] = '$60.00'
        row['Points'] = 00
        row['Contr.Acc Fine'] = '$60.00'
        row['Contr.Acc Points'] = 00
        row['Description'] = 'Failure of veh. on hwy. to display (lighted lamps, illuminating devices) in unfavorable visibility conditions'

    if row['Charge'] == '21-201.1':
        row['Fine'] = '$90.00'
        row['Points'] = 1
        row['Contr.Acc Fine'] = '$130.00'
        row['Contr.Acc Points'] = 3
        row['Description'] = 'Driver failure to obey properly placed traffic control device instructions'




    if row['Charge'] == '22-219(a)':
        row['Fine'] = '$70.00'
        row['Points'] = 0
        row['Contr.Acc Fine'] = '$70.00'
        row['Contr.Acc Points'] = 0
        row['Description'] = 'Failure to equip veh. with required rear red stop lamp visible from a distance of not less than 300 ft to the rear in normal sunlight'


    if row['Charge'] == '23-104':
        row['Fine'] = '$70.00'
        row['Points'] = 0
        row['Contr.Acc Fine'] = '$70.00'
        row['Contr.Acc Points'] = 0
        row['Description'] = 'Driving (motor veh., autocycle, low speed veh.) not in accordance with established equipment, performance, and other technical standards'
    return row

merged_df = merged_df.apply(update_fine_details, axis=1)

# %% [markdown]
# **Merging Fine and Charge**

# %%
merged_df = merged_df[~((merged_df['Fine'].isna()) & (merged_df['Charge'].str.contains('-', na=False)))]

# %% [markdown]
# **Generating Section Titles**

# %%
data = {
    "Charge": ["21-1201", "22-101", "24-111", "13-101", "14-110", "26-101", "26-408.1"],
}
df = pd.DataFrame(data)


section_ranges = {
    "Motor Vehicle Administration": ("12-101", "12-209"),
    "Certificates of Title and Registration of Vehicles": ("13-101", "13-955"),
    "Anti-Theft Laws and Related Provisions": ("14-101", "14-110"),
    "For Rental Vehicles": ("15-201", "15-213"),
    "Licensing of Businesses and Occupations": ("15-101", "15-704"),
    "Drivers' Licenses": ("16-101", "16-819"),
    "Financial Responsibility and Vehicle Registration": ("17-101", "17-110"),
    "Civil Liability of Governmental Agencies": ("18-101", "18-106"),
    "Accidents and Accident Reports": ("20-101", "20-110"),
    "Rules of Road": ("21-101", "21-708"),
    "Speed Restrictions": ("21-800", "21-806"),
    "Driving Offenses": ("21-901.1", "21-902"),
    "Parking Violations": ("21-1001", "21-1007"),
    "Miscellaneous Rules": ("21-1101", "21-1119"),
    "Operation of Bicycles and Play Vehicles": ("21-1201", "21-1213"),
    "Operation of Motorcycles": ("21-1301", "21-1307"),
    "Operation of Vehicles on Certain Toll Facilities": ("21-1401", "21-1411"),
    "Equipment of Vehicles": ("22-101", "22-610"),
    "Inspection of Used Vehicles and Warnings for Defective Equipment": ("23-101", "23-208"),
    "Size, Weight, and Load; Highway Preservation": ("24-101", "24-111"),
    "Respective Powers of State and Local Authorities": ("25-101", "25-210"),
    "Parties and Procedures on Citation, Arrest, Trial, and Appeal": ("26-101", "26-408.1")
}


def map_to_section(charge):
    for section, (start, end) in section_ranges.items():
        if start <= charge <= end:
            return section
    return "Unknown Section"


merged_df["Section"] = merged_df["Charge"].apply(map_to_section)
# Out:
#                                     SeqID Date Of Stop Time Of Stop Agency  \
# 0    35333459-ff22-4f0a-b69e-a7ad633be9c9   2025-01-02     19:43:00    MCP
# 1    fb58b70b-58cc-44b9-b81a-6971bd89e3c6   2025-01-01     04:51:00    MCP
# 2    770d0b11-a4cf-4cc2-b821-047a54875fe9   2025-01-02     11:18:00    MCP
# 3    c3ee4476-6e6b-4a33-a0d7-a9beafd43e9f   2025-01-03     12:50:00    MCP
# 4    25afec33-dbc5-4a13-abc9-eb345a7c856e   2025-01-03     07:39:00    MCP
# ..                                    ...          ...          ...    ...
# 629  512cfa88-42cb-42df-919a-b8d15db9700e   2025-01-02     10:47:00    MCP
# 630  9b29c1d1-b3ee-4a21-a32c-976397006dd2   2025-01-02     10:34:00    MCP
# 631  1267d828-7739-47ef-b840-e7c68b15e29f   2025-01-01     22:32:00    MCP
# 632  57e7538d-12ec-4814-a738-324b7d4fcf90   2025-01-02     20:09:00    MCP
# 633  5e57fd43-121d-4025-88db-4c2ba5b5583a   2025-01-03     02:56:00    MCP
#
#                                            SubAgency  \
# 0    6th District, Gaithersburg / Montgomery Village
# 1                        3rd District, Silver Spring
# 2                Headquarters and Special Operations
# 3                Headquarters and Special Operations
# 4                Headquarters and Special Operations
# ..                                               ...
# 629              Headquarters and Special Operations
# 630              Headquarters and Special Operations
# 631                         5th District, Germantown
# 632                         5th District, Germantown
# 633                           2nd District, Bethesda
#
#                                          Description_x  \
# 0                  KNOWINGLY DRIVING UNINSURED VEHICLE
# 1    FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAM...
# 2                                          WINDOW TINT
# 3                                          WINDOW TINT
# 4           EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH
# ..                                                 ...
# 629                                        WINDOW TINT
# 630                                        WINDOW TINT
# 631                                     TAILLIGHTS (*)
# 632                                    STOP LIGHTS (*)
# 633                                    STOP LIGHTS (*)
#
#                         Location   Latitude  Longitude Accident  ...  \
# 0        SAM EIG HWY @ FIELDS RD  39.115861 -77.208437       No  ...
# 1    COLESVILLE RD @ HASTINGS DR  39.013269 -77.016302       No  ...
# 2       RANDOLOPH / HUNTERS LANE  39.053935 -77.101225       No  ...
# 3                 E GUDE / DOVER  39.098282 -77.137428       No  ...
# 4     RANDOLPH RD/TIMBER VIEW CT  39.184407 -77.263585       No  ...
# ..                           ...        ...        ...      ...  ...
# 629              220 RANDOLPH RD  39.069464 -77.014071       No  ...
# 630              310 RANDOLPH RD  39.069078 -77.014510       No  ...
# 631           CLOOPER @ ALLSPICE  39.150045 -77.244195       No  ...
# 632  MIDDLEBROOK @ FATHER HURLEY  39.182712 -77.274797       No  ...
# 633      RANDOLPH AT PARKLAWN DR  39.053640 -77.105406       No  ...
#
#            Arrest Type Charge Hierarchy               Charge Description  \
# 0    A - Marked Patrol           17-107                              NaN
# 1    A - Marked Patrol         22-201.1  When Lighted Lamps Are Required
# 2    A - Marked Patrol               61                             TINT
# 3    A - Marked Patrol               61                             TINT
# 4    A - Marked Patrol         21-801.1                   Maximum Limits
# ..                 ...              ...                              ...
# 629     L - Motorcycle               61                             TINT
# 630     L - Motorcycle               61                             TINT
# 631  A - Marked Patrol              56*                       Taillights
# 632  A - Marked Patrol              64*                      Stop Lights
# 633  A - Marked Patrol              64*                      Stop Lights
#
#                                            Description     Fine Points  \
# 0                  Knowingly driving uninsured vehicle       MA    5.0
# 1    Failure of veh. on hwy. to display (lighted la...   $60.00    0.0
# 2                                                  NaN      NaN    NaN
# 3                                                  NaN      NaN    NaN
# 4                                                  NaN  $530.00    5.0
# ..                                                 ...      ...    ...
# 629                                                NaN      NaN    NaN
# 630                                                NaN      NaN    NaN
# 631                                                NaN      NaN    NaN
# 632                                                NaN      NaN    NaN
# 633                                                NaN      NaN    NaN
#
#     Contr.Acc Fine Contr.Acc Points                     Fine Description  \
# 0               MA              5.0  Knowingly driving uninsured vehicle
# 1           $60.00              0.0                                  NaN
# 2              NaN              NaN                                  NaN
# 3              NaN              NaN                                  NaN
# 4          $530.00              5.0                                  NaN
# ..             ...              ...                                  ...
# 629            NaN              NaN                                  NaN
# 630            NaN              NaN                                  NaN
# 631            NaN              NaN                                  NaN
# 632            NaN              NaN                                  NaN
# 633            NaN              NaN                                  NaN
#
#                                                Section
# 0    Financial Responsibility and Vehicle Registration
# 1                                Equipment of Vehicles
# 2                                      Unknown Section
# 3                                      Unknown Section
# 4                                   Speed Restrictions
# ..                                                 ...
# 629                                    Unknown Section
# 630                                    Unknown Section
# 631                                    Unknown Section
# 632                                    Unknown Section
# 633                                    Unknown Section
#
# [567 rows x 50 columns]

# %% [markdown]
# **Dropping Attributes**

# %%
new_df = merged_df.drop(columns=[ 'Description', 'Fine Description'])
new_df = new_df.rename(columns={ 'Description_x': 'Description'})

# %%
new_df.to_csv('Maryland_Traffic_Violation_2025.csv', index=False)

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
import time
from requests.exceptions import ReadTimeout, ConnectTimeout
import logging
from tenacity import retry, stop_after_attempt, wait_exponential

# %% [markdown]
# **Generating Driver_City_Latitude and Driver_City_Longitude based on Driver City Attribute**

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def add_city_coordinates(df):

    geolocator = Nominatim(user_agent="my_traffic_app", timeout=10)


    city_coords_cache = {}

    @retry(
        stop=stop_after_attempt(3),
        wait=wait_exponential(multiplier=1, min=4, max=10),
        retry_error_callback=lambda _: (None, None)
    )
    def get_coordinates_with_retry(city_name):

        location = geolocator.geocode(city_name)
        if location:
            return location.latitude, location.longitude
        return None, None

    def get_coordinates(city):

        if pd.isna(city):
            return None, None

        city = str(city).strip().upper()
        search_term = f"{city}, USA"

        if search_term in city_coords_cache:
            return city_coords_cache[search_term]

        try:
            coords = get_coordinates_with_retry(search_term)
            if coords != (None, None):
                city_coords_cache[search_term] = coords
            return coords

        except (GeocoderTimedOut, GeocoderUnavailable, ReadTimeout, ConnectTimeout) as e:
            logger.warning(f"Geocoding failed for {city}: {str(e)}")
            return None, None
        except Exception as e:
            logger.error(f"Unexpected error for {city}: {str(e)}")
            return None, None


    unique_cities = df['Driver City'].dropna().unique()
    total_cities = len(unique_cities)
    logger.info(f"Processing {total_cities} unique cities...")


    city_coords = {}
    for i, city in enumerate(unique_cities, 1):
        lat, lon = get_coordinates(city)
        city_coords[city] = {'lat': lat, 'lon': lon}


        if i % 10 == 0:
            logger.info(f"Processed {i}/{total_cities} cities ({(i/total_cities*100):.1f}%)")


        time.sleep(0.5)

    df['Driver_City_Latitude'] = df['Driver City'].map(lambda x: city_coords.get(x, {}).get('lat'))
    df['Driver_City_Longitude'] = df['Driver City'].map(lambda x: city_coords.get(x, {}).get('lon'))


    total_records = len(df['Driver City'].dropna())
    records_with_coords = len(df[df['Driver_City_Latitude'].notna()])
    logger.info("\nGeocoding Summary:")
    logger.info(f"Total cities processed: {total_records}")
    logger.info(f"Cities with coordinates: {records_with_coords}")
    logger.info(f"Success rate: {(records_with_coords/total_records*100):.1f}%")


    cache_df = pd.DataFrame.from_dict(
        {k: [v['lat'], v['lon']] for k, v in city_coords.items()},
        orient='index',
        columns=['latitude', 'longitude']
    )
    cache_df.to_csv('city_coordinates_cache.csv')

    return df
df = pd.read_csv('Maryland_Traffic_Violation_2025.csv')
df = add_city_coordinates(df)

# %%
df.to_csv('Maryland_Traffic_Violation_2025.csv', index=False)
